# %% [markdown]
# # CartPole Using Q-Learning
#
# [CartPole Documentation](https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py)
#
# ### Action Space
#
# The action is a `ndarray` with shape `(1,)` which can take values `{0, 1}` indicating the direction of the fixed force the cart is pushed with.
#
# | Num | Action                 |
# |-----|------------------------|
# | 0   | Push cart to the left  |
# | 1   | Push cart to the right |
#
# **Note**: The velocity that is reduced or increased by the applied force is not fixed and it depends on the angle the pole is pointing. The center of gravity of the pole varies the amount of energy needed to move the cart underneath it
#
# ### Observation Space
#
# The observation is a `ndarray` with shape `(4,)` with the values corresponding to the following positions and velocities:
#
# | Num | Observation           | Min                 | Max               |
# |-----|-----------------------|---------------------|-------------------|
# | 0   | Cart Position         | -4.8                | 4.8               |
# | 1   | Cart Velocity         | -Inf                | Inf               |
# | 2   | Pole Angle            | ~ -0.418 rad (-24°) | ~ 0.418 rad (24°) |
# | 3   | Pole Angular Velocity | -Inf                | Inf               |
#
# **Note:** While the ranges above denote the possible values for observation space of each element, it is not reflective of the allowed values of the state space in an unterminated episode. Particularly:
#
# - The cart x-position (index 0) can be take values between `(-4.8, 4.8)`, but the episode terminates if the cart leaves the `(-2.4, 2.4)` range.
# - The pole angle can be observed between  `(-.418, .418)` radians (or **±24°**), but the episode terminates if the pole angle is not in the range `(-.2095, .2095)` (or **±12°**)

# %% [markdown]
# ## Q-Learning Table
#
# | Num | Start | Step Width | Steps (Inc. 0) |
# |-----|-------|------------|----------------|
# | 0   | -2.4  | 0.1        | 48 + 1         |
# | 1   | -4    | 0.01       | 800 + 1        |
# | 2   | -12   | 1°         | 24 + 1         |
# | 3   | -4    | 0.01       | 800 + 1        |

# %%
import gym
import math
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Testing with all 4 observations spaces
#
# - Not actually necessary
# - Truly only need a q-table for all the angles the pole can be at

# %%
""" Searching for ranges of observation space """

"""
env = gym.make("CartPole-v1")

min_vals = [0, 0, 0, 0]
max_vals = [0, 0, 0, 0]

episodes = 100000
for i_ep in range(episodes):
    # print("Episode:", i_ep + 1)

    obs = env.reset()
    done = False

    while not done:
        # env.render()

        action = env.action_space.sample()

        obs, reward, done, _ = env.step(action)
        
        if done: 
            break
        
        for i in range(len(obs)):
            min_vals[i] = min(obs[i], min_vals[i])
            max_vals[i] = max(obs[i], max_vals[i])

print("Min:", min_vals)
print("Max:", max_vals)
"""
# Out:
# '\nenv = gym.make("CartPole-v1")\n\nmin_vals = [0, 0, 0, 0]\nmax_vals = [0, 0, 0, 0]\n\nepisodes = 100000\nfor i_ep in range(episodes):\n    # print("Episode:", i_ep + 1)\n\n    obs = env.reset()\n    done = False\n\n    while not done:\n        # env.render()\n\n        action = env.action_space.sample()\n\n        obs, reward, done, _ = env.step(action)\n        \n        if done: \n            break\n        \n        for i in range(len(obs)):\n            min_vals[i] = min(obs[i], min_vals[i])\n            max_vals[i] = max(obs[i], max_vals[i])\n\nprint("Min:", min_vals)\nprint("Max:", max_vals)\n'

# %%
"""
q_table_params = {
    "start": [-2.4, -4, -12, -4],
    "step": [1, 2, 0, 2], # In digits after the decimal point
    "steps": [49, 801, 25, 801],
}

q_table = np.array(
    [np.zeros((steps_val,)) for steps_val in q_table_params["steps"]], dtype="object"
)
"""
# Out:
# '\nq_table_params = {\n    "start": [-2.4, -4, -12, -4],\n    "step": [1, 2, 0, 2], # In digits after the decimal point\n    "steps": [49, 801, 25, 801],\n}\n\nq_table = np.array(\n    [np.zeros((steps_val,)) for steps_val in q_table_params["steps"]], dtype="object"\n)\n'

# %%
""" Check to make sure that all continuous observations have translated to discrete spaces """

"""
env = gym.make("CartPole-v1")

episodes = 10000
for i_ep in range(episodes):
    obs = env.reset()
    done = False

    while not done:
        action = env.action_space.sample()

        obs, reward, done, _ = env.step(action)
        
        if done:
            break # Skips adding last observation to q-table

        for i in range(len(obs)):
            step = q_table_params["step"][i]
            
            power = 10 ** step
            
            if i == 2:
                val = math.degrees(obs[i])
            else:
                val = obs[i]
            
            index = int(round(val, step) * power)
            q_table[i][index] += 1

print(q_table[0])
"""
# Out:
# '\nenv = gym.make("CartPole-v1")\n\nepisodes = 10000\nfor i_ep in range(episodes):\n    obs = env.reset()\n    done = False\n\n    while not done:\n        action = env.action_space.sample()\n\n        obs, reward, done, _ = env.step(action)\n        \n        if done:\n            break # Skips adding last observation to q-table\n\n        for i in range(len(obs)):\n            step = q_table_params["step"][i]\n            \n            power = 10 ** step\n            \n            if i == 2:\n                val = math.degrees(obs[i])\n            else:\n                val = obs[i]\n            \n            index = int(round(val, step) * power)\n            q_table[i][index] += 1\n\nprint(q_table[0])\n'

# %% [markdown]
# ## Q-Learning Agent Implementation

# %%
ALPHA = (
    0.5  # Learning rate -> how fast the values are propagated throughout the q-table
)
GAMMA = 0.9  # Discount factor -> how much the rewards are discounted from future steps
EPSILON = 0.1  # Greedy function -> exploration vs exploitation -> chance for the agent to make an educated guess

REWARD_SHAPING = -1000

EPISODE_LEN = 200
ENV_NAME = "CartPole-v1"

# %% [markdown]
# [Generating Docstrings](https://queirozf.com/entries/python-docstrings-reference-examples#:~:text=Python%20Docstrings%3A%20Reference%20%26%20Examples%201%20ReStructuredText%20%28reST%29,description%20of%20function.%20...%204%20Doctest%20Permalink.%20)

# %%
def discrete(observation):
    radians = observation[2]
    degrees = math.degrees(radians)
    rounded_degress = round(degrees)

    """Simplified architecture"""
    
    """
    if rounded_degress < 0:
        return -1
    if rounded_degress > 0:
        return 1
    return 0
    """

    """Per degree architecture"""

    return round(degrees)


def greedy():
    return np.random.rand() > EPSILON


def q_func(reward, q_current_value, q_forward_value):
    """Returns q_value to update q_table with"""

    q_value = q_current_value + ALPHA * (reward + GAMMA * q_forward_value - q_current_value)
    return q_value


def train(agent, episodes, render=False):
    scores = []

    for i in range(episodes):
        score = agent.evaluate(render)
        print("Episode:", i + 1, "\tScore:", score)

        scores.append(score)

    return scores


def graph(values):
    plt.plot(values)

    plt.title("Training Data")
    plt.xlabel("Episodes")
    plt.ylabel("Score")

    plt.show()

# %%
class QAgent:
    def __init__(self):
        # self.q_table = np.zeros((3, 2))  # Simplified architecture
        self.q_table = np.zeros((29, 2)) # Per degree architecture

        self.env = None
        self.make()

    def _forward(self, state, overrideGreedy=False):
        env = self.env
        q_table = self.q_table

        if not greedy() and not overrideGreedy:
            return env.action_space.sample()

        return np.argmax(q_table[state])

    def evaluate(self, render=False):
        """Evaluate Q-Learning Agent

        :param int cur_obs: Current observation state
        :param int for_obs: Forward observation state
        :param int cur_action: Current action state
        :param int for_action: Forward action state
        :param int rew: Forward observation reward
        :param float q_cur_val: Q-value of current state, current action -> Q(s, a)
        :param float q_for_val: Q-value of forward state, forward action -> Q(s', a')
        """

        env = self.env
        q_table = self.q_table

        cur_obs = discrete(env.reset())
        cur_action = self._forward(cur_obs)

        done = False
        score = 0
        step = 0

        while not done:
            if step == EPISODE_LEN:
                break

            if render:
                env.render()

            for_action = self._forward(cur_obs)

            for_obs, rew, done, _ = env.step(for_action)

            for_obs = discrete(for_obs)

            if done:
                pass
                rew = REWARD_SHAPING

            q_cur_val = q_table[cur_obs][cur_action]
            q_for_val = q_table[for_obs][self._forward(cur_obs, overrideGreedy=True)]
            q_value = q_func(rew, q_cur_val, q_for_val)
            q_table[cur_obs][cur_action] = q_value

            cur_obs = for_obs
            cur_action = for_action
            score += rew
            step += 1
            
        self.q_table = q_table

        return score

    def make(self):
        if self.env is None:
            env = gym.make(ENV_NAME)
            env._max_episode_steps = EPISODE_LEN
            self.env = env

    def close(self):
        if self.env is not None:
            self.env.close()
            self.env = None

# %%
a = QAgent()

# %%
""" 
scores = train(a, 1000)
graph(scores)
"""
# Out:
# Episode: 1 	Score: -992.0
# Episode: 2 	Score: -980.0
# Episode: 3 	Score: -940.0
# Episode: 4 	Score: -975.0
# Episode: 5 	Score: -981.0
# Episode: 6 	Score: -990.0
# Episode: 7 	Score: -989.0
# Episode: 8 	Score: -983.0
# Episode: 9 	Score: -965.0
# Episode: 10 	Score: -978.0
# Episode: 11 	Score: -973.0
# Episode: 12 	Score: -982.0
# Episode: 13 	Score: -987.0
# Episode: 14 	Score: -987.0
# Episode: 15 	Score: -974.0
# Episode: 16 	Score: -951.0
# Episode: 17 	Score: -970.0
# Episode: 18 	Score: -969.0
# Episode: 19 	Score: -983.0
# Episode: 20 	Score: -940.0
# Episode: 21 	Score: -959.0
# Episode: 22 	Score: -981.0
# Episode: 23 	Score: -983.0
# Episode: 24 	Score: -971.0
# Episode: 25 	Score: -977.0
# Episode: 26 	Score: -971.0
# Episode: 27 	Score: -983.0
# Episode: 28 	Score: -979.0
# Episode: 29 	Score: -938.0
# Episode: 30 	Score: -962.0
# Episode: 31 	Score: -968.0
# Episode: 32 	Score: -967.0
# Episode: 33 	Score: -971.0
# Episode: 34 	Score: -931.0
# Episode: 35 	Score: -989.0
# Episode: 36 	Score: -957.0
# Episode: 37 	Score: -977.0
# Episode: 38 	Score: -941.0
# Episode: 39 	Score: -990.0
# Episode: 40 	Score: -963.0
# Episode: 41 	Score: -978.0
# Episode: 42 	Score: -988.0
# Episode: 43 	Score: -978.0
# Episode: 44 	Score: -980.0
# Episode: 45 	Score: -988.0
# Episode: 46 	Score: -989.0
# Episode: 47 	Score: -987.0
# Episode: 48 	Score: -983.0
# Episode: 49 	Score: -987.0
# Episode: 50 	Score: -968.0
# Episode: 51 	Score: -974.0
# Episode: 52 	Score: -934.0
# Episode: 53 	Score: -963.0
# Episode: 54 	Score: -973.0
# Episode: 55 	Score: -987.0
# Episode: 56 	Score: -987.0
# Episode: 57 	Score: -983.0
# Episode: 58 	Score: -984.0
# Episode: 59 	Score: -985.0
# Episode: 60 	Score: -981.0
# Episode: 61 	Score: -980.0
# Episode: 62 	Score: -983.0
# Episode: 63 	Score: -953.0
# Episode: 64 	Score: -987.0
# Episode: 65 	Score: -989.0
# Episode: 66 	Score: -989.0
# Episode: 67 	Score: -985.0
# Episode: 68 	Score: -989.0
# Episode: 69 	Score: -966.0
# Episode: 70 	Score: -899.0
# Episode: 71 	Score: -973.0
# Episode: 72 	Score: -982.0
# Episode: 73 	Score: -989.0
# Episode: 74 	Score: -991.0
# Episode: 75 	Score: -988.0
# Episode: 76 	Score: -968.0
# Episode: 77 	Score: -986.0
# Episode: 78 	Score: -981.0
# Episode: 79 	Score: -987.0
# Episode: 80 	Score: -961.0
# Episode: 81 	Score: -987.0
# Episode: 82 	Score: -989.0
# Episode: 83 	Score: -973.0
# Episode: 84 	Score: -983.0
# Episode: 85 	Score: -982.0
# Episode: 86 	Score: -978.0
# Episode: 87 	Score: -937.0
# Episode: 88 	Score: -958.0
# Episode: 89 	Score: -985.0
# Episode: 90 	Score: -935.0
# Episode: 91 	Score: -987.0
# Episode: 92 	Score: -950.0
# Episode: 93 	Score: -988.0
# Episode: 94 	Score: -970.0
# Episode: 95 	Score: -989.0
# Episode: 96 	Score: -978.0
# Episode: 97 	Score: -977.0
# Episode: 98 	Score: -983.0
# Episode: 99 	Score: -948.0
# Episode: 100 	Score: -921.0
# Episode: 101 	Score: -972.0
# Episode: 102 	Score: -955.0
# Episode: 103 	Score: -962.0
# Episode: 104 	Score: -977.0
# Episode: 105 	Score: -971.0
# Episode: 106 	Score: -977.0
# Episode: 107 	Score: -987.0
# Episode: 108 	Score: -982.0
# Episode: 109 	Score: -991.0
# Episode: 110 	Score: -988.0
# Episode: 111 	Score: -982.0
# Episode: 112 	Score: -988.0
# Episode: 113 	Score: -911.0
# Episode: 114 	Score: -974.0
# Episode: 115 	Score: -987.0
# Episode: 116 	Score: -985.0
# Episode: 117 	Score: -988.0
# Episode: 118 	Score: -987.0
# Episode: 119 	Score: -941.0
# Episode: 120 	Score: -975.0
# Episode: 121 	Score: -989.0
# Episode: 122 	Score: -962.0
# Episode: 123 	Score: -988.0
# Episode: 124 	Score: -969.0
# Episode: 125 	Score: -988.0
# Episode: 126 	Score: -970.0
# Episode: 127 	Score: -977.0
# Episode: 128 	Score: -923.0
# Episode: 129 	Score: -992.0
# Episode: 130 	Score: -986.0
# Episode: 131 	Score: -981.0
# Episode: 132 	Score: -973.0
# Episode: 133 	Score: -980.0
# Episode: 134 	Score: -976.0
# Episode: 135 	Score: -960.0
# Episode: 136 	Score: -977.0
# Episode: 137 	Score: -986.0
# Episode: 138 	Score: -968.0
# Episode: 139 	Score: -990.0
# Episode: 140 	Score: -970.0
# Episode: 141 	Score: -925.0
# Episode: 142 	Score: -990.0
# Episode: 143 	Score: -981.0
# Episode: 144 	Score: -967.0
# Episode: 145 	Score: -986.0
# Episode: 146 	Score: -989.0
# Episode: 147 	Score: -990.0
# Episode: 148 	Score: -967.0
# Episode: 149 	Score: -977.0
# Episode: 150 	Score: -960.0
# Episode: 151 	Score: -969.0
# Episode: 152 	Score: -964.0
# Episode: 153 	Score: -989.0
# Episode: 154 	Score: -984.0
# Episode: 155 	Score: -990.0
# Episode: 156 	Score: -985.0
# Episode: 157 	Score: -971.0
# Episode: 158 	Score: -954.0
# Episode: 159 	Score: -987.0
# Episode: 160 	Score: -972.0
# Episode: 161 	Score: -985.0
# Episode: 162 	Score: -986.0
# Episode: 163 	Score: -990.0
# Episode: 164 	Score: -979.0
# Episode: 165 	Score: -986.0
# Episode: 166 	Score: -986.0
# Episode: 167 	Score: -977.0
# Episode: 168 	Score: -990.0
# Episode: 169 	Score: -985.0
# Episode: 170 	Score: -983.0
# Episode: 171 	Score: -986.0
# Episode: 172 	Score: -990.0
# Episode: 173 	Score: -970.0
# Episode: 174 	Score: -988.0
# Episode: 175 	Score: -990.0
# Episode: 176 	Score: -986.0
# Episode: 177 	Score: -983.0
# Episode: 178 	Score: -979.0
# Episode: 179 	Score: -989.0
# Episode: 180 	Score: -986.0
# Episode: 181 	Score: -962.0
# Episode: 182 	Score: -976.0
# Episode: 183 	Score: -992.0
# Episode: 184 	Score: -982.0
# Episode: 185 	Score: -963.0
# Episode: 186 	Score: -991.0
# Episode: 187 	Score: -992.0
# Episode: 188 	Score: -988.0
# Episode: 189 	Score: -946.0
# Episode: 190 	Score: -985.0
# Episode: 191 	Score: -977.0
# Episode: 192 	Score: -974.0
# Episode: 193 	Score: -949.0
# Episode: 194 	Score: -992.0
# Episode: 195 	Score: -988.0
# Episode: 196 	Score: -957.0
# Episode: 197 	Score: -906.0
# Episode: 198 	Score: -975.0
# Episode: 199 	Score: -991.0
# Episode: 200 	Score: -988.0
# Episode: 201 	Score: -964.0
# Episode: 202 	Score: -963.0
# Episode: 203 	Score: -990.0
# Episode: 204 	Score: -962.0
# Episode: 205 	Score: -944.0
# Episode: 206 	Score: -990.0
# Episode: 207 	Score: -975.0
# Episode: 208 	Score: -939.0
# Episode: 209 	Score: -987.0
# Episode: 210 	Score: -984.0
# Episode: 211 	Score: -986.0
# Episode: 212 	Score: -871.0
# Episode: 213 	Score: -914.0
# Episode: 214 	Score: -988.0
# Episode: 215 	Score: -987.0
# Episode: 216 	Score: -990.0
# Episode: 217 	Score: -981.0
# Episode: 218 	Score: -983.0
# Episode: 219 	Score: -979.0
# Episode: 220 	Score: -989.0
# Episode: 221 	Score: -987.0
# Episode: 222 	Score: -956.0
# Episode: 223 	Score: -980.0
# Episode: 224 	Score: -977.0
# Episode: 225 	Score: -976.0
# Episode: 226 	Score: -984.0
# Episode: 227 	Score: -943.0
# Episode: 228 	Score: -974.0
# Episode: 229 	Score: -968.0
# Episode: 230 	Score: -964.0
# Episode: 231 	Score: -979.0
# Episode: 232 	Score: -987.0
# Episode: 233 	Score: -985.0
# Episode: 234 	Score: -967.0
# Episode: 235 	Score: -991.0
# Episode: 236 	Score: -988.0
# Episode: 237 	Score: -984.0
# Episode: 238 	Score: -982.0
# Episode: 239 	Score: -960.0
# Episode: 240 	Score: -986.0
# Episode: 241 	Score: -991.0
# Episode: 242 	Score: -974.0
# Episode: 243 	Score: -979.0
# Episode: 244 	Score: -976.0
# Episode: 245 	Score: -984.0
# Episode: 246 	Score: -944.0
# Episode: 247 	Score: -976.0
# Episode: 248 	Score: -951.0
# Episode: 249 	Score: -990.0
# Episode: 250 	Score: -974.0
# Episode: 251 	Score: -975.0
# Episode: 252 	Score: -973.0
# Episode: 253 	Score: -987.0
# Episode: 254 	Score: -988.0
# Episode: 255 	Score: -973.0
# Episode: 256 	Score: -989.0
# Episode: 257 	Score: -985.0
# Episode: 258 	Score: -987.0
# Episode: 259 	Score: -987.0
# Episode: 260 	Score: -972.0
# Episode: 261 	Score: -991.0
# Episode: 262 	Score: -990.0
# Episode: 263 	Score: -976.0
# Episode: 264 	Score: -988.0
# Episode: 265 	Score: -984.0
# Episode: 266 	Score: -988.0
# Episode: 267 	Score: -954.0
# Episode: 268 	Score: -976.0
# Episode: 269 	Score: -947.0
# Episode: 270 	Score: -990.0
# Episode: 271 	Score: -977.0
# Episode: 272 	Score: -977.0
# Episode: 273 	Score: -974.0
# Episode: 274 	Score: -989.0
# Episode: 275 	Score: -912.0
# Episode: 276 	Score: -964.0
# Episode: 277 	Score: -980.0
# Episode: 278 	Score: -947.0
# Episode: 279 	Score: -965.0
# Episode: 280 	Score: -988.0
# Episode: 281 	Score: -991.0
# Episode: 282 	Score: -988.0
# Episode: 283 	Score: -988.0
# Episode: 284 	Score: -989.0
# Episode: 285 	Score: -969.0
# Episode: 286 	Score: -975.0
# Episode: 287 	Score: -989.0
# Episode: 288 	Score: -980.0
# Episode: 289 	Score: -988.0
# Episode: 290 	Score: -980.0
# Episode: 291 	Score: -989.0
# Episode: 292 	Score: -985.0
# Episode: 293 	Score: -982.0
# Episode: 294 	Score: -949.0
# Episode: 295 	Score: -950.0
# Episode: 296 	Score: -988.0
# Episode: 297 	Score: -983.0
# Episode: 298 	Score: -972.0
# Episode: 299 	Score: -979.0
# Episode: 300 	Score: -939.0
# Episode: 301 	Score: -978.0
# Episode: 302 	Score: -970.0
# Episode: 303 	Score: -987.0
# Episode: 304 	Score: -975.0
# Episode: 305 	Score: -987.0
# Episode: 306 	Score: -963.0
# Episode: 307 	Score: -992.0
# Episode: 308 	Score: -985.0
# Episode: 309 	Score: -979.0
# Episode: 310 	Score: -987.0
# Episode: 311 	Score: -989.0
# Episode: 312 	Score: -991.0
# Episode: 313 	Score: -988.0
# Episode: 314 	Score: -977.0
# Episode: 315 	Score: -928.0
# Episode: 316 	Score: -964.0
# Episode: 317 	Score: -971.0
# Episode: 318 	Score: -968.0
# Episode: 319 	Score: -972.0
# Episode: 320 	Score: -979.0
# Episode: 321 	Score: -986.0
# Episode: 322 	Score: -988.0
# Episode: 323 	Score: -985.0
# Episode: 324 	Score: -975.0
# Episode: 325 	Score: -966.0
# Episode: 326 	Score: -979.0
# Episode: 327 	Score: -978.0
# Episode: 328 	Score: -981.0
# Episode: 329 	Score: -952.0
# Episode: 330 	Score: -983.0
# Episode: 331 	Score: -984.0
# Episode: 332 	Score: -985.0
# Episode: 333 	Score: -990.0
# Episode: 334 	Score: -956.0
# Episode: 335 	Score: -983.0
# Episode: 336 	Score: -946.0
# Episode: 337 	Score: -984.0
# Episode: 338 	Score: -969.0
# Episode: 339 	Score: -988.0
# Episode: 340 	Score: -972.0
# Episode: 341 	Score: -971.0
# Episode: 342 	Score: -979.0
# Episode: 343 	Score: -986.0
# Episode: 344 	Score: -990.0
# Episode: 345 	Score: -979.0
# Episode: 346 	Score: -971.0
# Episode: 347 	Score: -974.0
# Episode: 348 	Score: -991.0
# Episode: 349 	Score: -975.0
# Episode: 350 	Score: -977.0
# Episode: 351 	Score: -984.0
# Episode: 352 	Score: -979.0
# Episode: 353 	Score: -970.0
# Episode: 354 	Score: -990.0
# Episode: 355 	Score: -970.0
# Episode: 356 	Score: -980.0
# Episode: 357 	Score: -943.0
# Episode: 358 	Score: -917.0
# Episode: 359 	Score: -975.0
# Episode: 360 	Score: -953.0
# Episode: 361 	Score: -985.0
# Episode: 362 	Score: -991.0
# Episode: 363 	Score: -954.0
# Episode: 364 	Score: -982.0
# Episode: 365 	Score: -971.0
# Episode: 366 	Score: -971.0
# Episode: 367 	Score: -981.0
# Episode: 368 	Score: -975.0
# Episode: 369 	Score: -971.0
# Episode: 370 	Score: -989.0
# Episode: 371 	Score: -988.0
# Episode: 372 	Score: -977.0
# Episode: 373 	Score: -985.0
# Episode: 374 	Score: -956.0
# Episode: 375 	Score: -970.0
# Episode: 376 	Score: -975.0
# Episode: 377 	Score: -985.0
# Episode: 378 	Score: -978.0
# Episode: 379 	Score: -981.0
# Episode: 380 	Score: -969.0
# Episode: 381 	Score: -967.0
# Episode: 382 	Score: -986.0
# Episode: 383 	Score: -934.0
# Episode: 384 	Score: -979.0
# Episode: 385 	Score: -989.0
# Episode: 386 	Score: -967.0
# Episode: 387 	Score: -987.0
# Episode: 388 	Score: -975.0
# Episode: 389 	Score: -966.0
# Episode: 390 	Score: -971.0
# Episode: 391 	Score: -989.0
# Episode: 392 	Score: -974.0
# Episode: 393 	Score: -958.0
# Episode: 394 	Score: -977.0
# Episode: 395 	Score: -984.0
# Episode: 396 	Score: -965.0
# Episode: 397 	Score: -990.0
# Episode: 398 	Score: -976.0
# Episode: 399 	Score: -992.0
# Episode: 400 	Score: -991.0
# Episode: 401 	Score: -985.0
# Episode: 402 	Score: -987.0
# Episode: 403 	Score: -989.0
# Episode: 404 	Score: -989.0
# Episode: 405 	Score: -988.0
# Episode: 406 	Score: -973.0
# Episode: 407 	Score: -992.0
# Episode: 408 	Score: -990.0
# Episode: 409 	Score: -989.0
# Episode: 410 	Score: -954.0
# Episode: 411 	Score: -976.0
# Episode: 412 	Score: -982.0
# Episode: 413 	Score: -984.0
# Episode: 414 	Score: -940.0
# Episode: 415 	Score: -981.0
# Episode: 416 	Score: -979.0
# Episode: 417 	Score: -984.0
# Episode: 418 	Score: -941.0
# Episode: 419 	Score: -984.0
# Episode: 420 	Score: -989.0
# Episode: 421 	Score: -990.0
# Episode: 422 	Score: -964.0
# Episode: 423 	Score: -966.0
# Episode: 424 	Score: -981.0
# Episode: 425 	Score: -954.0
# Episode: 426 	Score: -989.0
# Episode: 427 	Score: -977.0
# Episode: 428 	Score: -952.0
# Episode: 429 	Score: -987.0
# Episode: 430 	Score: -977.0
# Episode: 431 	Score: -981.0
# Episode: 432 	Score: -985.0
# Episode: 433 	Score: -974.0
# Episode: 434 	Score: -979.0
# Episode: 435 	Score: -984.0
# Episode: 436 	Score: -989.0
# Episode: 437 	Score: -990.0
# Episode: 438 	Score: -991.0
# Episode: 439 	Score: -990.0
# Episode: 440 	Score: -988.0
# Episode: 441 	Score: -980.0
# Episode: 442 	Score: -977.0
# Episode: 443 	Score: -945.0
# Episode: 444 	Score: -953.0
# Episode: 445 	Score: -980.0
# Episode: 446 	Score: -990.0
# Episode: 447 	Score: -987.0
# Episode: 448 	Score: -990.0
# Episode: 449 	Score: -935.0
# Episode: 450 	Score: -987.0
# Episode: 451 	Score: -985.0
# Episode: 452 	Score: -979.0
# Episode: 453 	Score: -984.0
# Episode: 454 	Score: -964.0
# Episode: 455 	Score: -970.0
# Episode: 456 	Score: -960.0
# Episode: 457 	Score: -988.0
# Episode: 458 	Score: -991.0
# Episode: 459 	Score: -959.0
# Episode: 460 	Score: -982.0
# Episode: 461 	Score: -963.0
# Episode: 462 	Score: -987.0
# Episode: 463 	Score: -978.0
# Episode: 464 	Score: -964.0
# Episode: 465 	Score: -990.0
# Episode: 466 	Score: -989.0
# Episode: 467 	Score: -936.0
# Episode: 468 	Score: -983.0
# Episode: 469 	Score: -960.0
# Episode: 470 	Score: -981.0
# Episode: 471 	Score: -989.0
# Episode: 472 	Score: -987.0
# Episode: 473 	Score: -971.0
# Episode: 474 	Score: -923.0
# Episode: 475 	Score: -989.0
# Episode: 476 	Score: -962.0
# Episode: 477 	Score: -984.0
# Episode: 478 	Score: -969.0
# Episode: 479 	Score: -965.0
# Episode: 480 	Score: -992.0
# Episode: 481 	Score: -980.0
# Episode: 482 	Score: -955.0
# Episode: 483 	Score: -989.0
# Episode: 484 	Score: -959.0
# Episode: 485 	Score: -992.0
# Episode: 486 	Score: -959.0
# Episode: 487 	Score: -988.0
# Episode: 488 	Score: -965.0
# Episode: 489 	Score: -960.0
# Episode: 490 	Score: -978.0
# Episode: 491 	Score: -931.0
# Episode: 492 	Score: -964.0
# Episode: 493 	Score: -977.0
# Episode: 494 	Score: -948.0
# Episode: 495 	Score: -985.0
# Episode: 496 	Score: -987.0
# Episode: 497 	Score: -983.0
# Episode: 498 	Score: -977.0
# Episode: 499 	Score: -946.0
# Episode: 500 	Score: -988.0
# Episode: 501 	Score: -986.0
# Episode: 502 	Score: -990.0
# Episode: 503 	Score: -954.0
# Episode: 504 	Score: -990.0
# Episode: 505 	Score: -988.0
# Episode: 506 	Score: -982.0
# Episode: 507 	Score: -975.0
# Episode: 508 	Score: -983.0
# Episode: 509 	Score: -982.0
# Episode: 510 	Score: -991.0
# Episode: 511 	Score: -986.0
# Episode: 512 	Score: -987.0
# Episode: 513 	Score: -990.0
# Episode: 514 	Score: -989.0
# Episode: 515 	Score: -974.0
# Episode: 516 	Score: -961.0
# Episode: 517 	Score: -981.0
# Episode: 518 	Score: -947.0
# Episode: 519 	Score: -947.0
# Episode: 520 	Score: -973.0
# Episode: 521 	Score: -987.0
# Episode: 522 	Score: -974.0
# Episode: 523 	Score: -964.0
# Episode: 524 	Score: -985.0
# Episode: 525 	Score: -989.0
# Episode: 526 	Score: -965.0
# Episode: 527 	Score: -984.0
# Episode: 528 	Score: -981.0
# Episode: 529 	Score: -988.0
# Episode: 530 	Score: -967.0
# Episode: 531 	Score: -990.0
# Episode: 532 	Score: -985.0
# Episode: 533 	Score: -970.0
# Episode: 534 	Score: -953.0
# Episode: 535 	Score: -989.0
# Episode: 536 	Score: -953.0
# Episode: 537 	Score: -976.0
# Episode: 538 	Score: -980.0
# Episode: 539 	Score: -980.0
# Episode: 540 	Score: -976.0
# Episode: 541 	Score: -984.0
# Episode: 542 	Score: -954.0
# Episode: 543 	Score: -983.0
# Episode: 544 	Score: -959.0
# Episode: 545 	Score: -984.0
# Episode: 546 	Score: -954.0
# Episode: 547 	Score: -987.0
# Episode: 548 	Score: -988.0
# Episode: 549 	Score: -989.0
# Episode: 550 	Score: -990.0
# Episode: 551 	Score: -970.0
# Episode: 552 	Score: -977.0
# Episode: 553 	Score: -982.0
# Episode: 554 	Score: -960.0
# Episode: 555 	Score: -958.0
# Episode: 556 	Score: -984.0
# Episode: 557 	Score: -974.0
# Episode: 558 	Score: -979.0
# Episode: 559 	Score: -958.0
# Episode: 560 	Score: -974.0
# Episode: 561 	Score: -991.0
# Episode: 562 	Score: -990.0
# Episode: 563 	Score: -985.0
# Episode: 564 	Score: -948.0
# Episode: 565 	Score: -987.0
# Episode: 566 	Score: -947.0
# Episode: 567 	Score: -991.0
# Episode: 568 	Score: -960.0
# Episode: 569 	Score: -988.0
# Episode: 570 	Score: -990.0
# Episode: 571 	Score: -992.0
# Episode: 572 	Score: -991.0
# Episode: 573 	Score: -992.0
# Episode: 574 	Score: -991.0
# Episode: 575 	Score: -990.0
# Episode: 576 	Score: -991.0
# Episode: 577 	Score: -990.0
# Episode: 578 	Score: -985.0
# Episode: 579 	Score: -985.0
# Episode: 580 	Score: -986.0
# Episode: 581 	Score: -980.0
# Episode: 582 	Score: -989.0
# Episode: 583 	Score: -984.0
# Episode: 584 	Score: -928.0
# Episode: 585 	Score: -970.0
# Episode: 586 	Score: -973.0
# Episode: 587 	Score: -980.0
# Episode: 588 	Score: -991.0
# Episode: 589 	Score: -990.0
# Episode: 590 	Score: -991.0
# Episode: 591 	Score: -985.0
# Episode: 592 	Score: -983.0
# Episode: 593 	Score: -978.0
# Episode: 594 	Score: -990.0
# Episode: 595 	Score: -990.0
# Episode: 596 	Score: -989.0
# Episode: 597 	Score: -988.0
# Episode: 598 	Score: -988.0
# Episode: 599 	Score: -987.0
# Episode: 600 	Score: -992.0
# Episode: 601 	Score: -969.0
# Episode: 602 	Score: -967.0
# Episode: 603 	Score: -984.0
# Episode: 604 	Score: -989.0
# Episode: 605 	Score: -978.0
# Episode: 606 	Score: -988.0
# Episode: 607 	Score: -987.0
# Episode: 608 	Score: -898.0
# Episode: 609 	Score: -981.0
# Episode: 610 	Score: -982.0
# Episode: 611 	Score: -983.0
# Episode: 612 	Score: -990.0
# Episode: 613 	Score: -983.0
# Episode: 614 	Score: -978.0
# Episode: 615 	Score: -989.0
# Episode: 616 	Score: -984.0
# Episode: 617 	Score: -989.0
# Episode: 618 	Score: -991.0
# Episode: 619 	Score: -983.0
# Episode: 620 	Score: -988.0
# Episode: 621 	Score: -978.0
# Episode: 622 	Score: -933.0
# Episode: 623 	Score: -970.0
# Episode: 624 	Score: -986.0
# Episode: 625 	Score: -987.0
# Episode: 626 	Score: -981.0
# Episode: 627 	Score: -960.0
# Episode: 628 	Score: -992.0
# Episode: 629 	Score: -969.0
# Episode: 630 	Score: -989.0
# Episode: 631 	Score: -978.0
# Episode: 632 	Score: -988.0
# Episode: 633 	Score: -982.0
# Episode: 634 	Score: -961.0
# Episode: 635 	Score: -977.0
# Episode: 636 	Score: -985.0
# Episode: 637 	Score: -985.0
# Episode: 638 	Score: -985.0
# Episode: 639 	Score: -956.0
# Episode: 640 	Score: -991.0
# Episode: 641 	Score: -942.0
# Episode: 642 	Score: -990.0
# Episode: 643 	Score: -987.0
# Episode: 644 	Score: -971.0
# Episode: 645 	Score: -971.0
# Episode: 646 	Score: -985.0
# Episode: 647 	Score: -981.0
# Episode: 648 	Score: -979.0
# Episode: 649 	Score: -987.0
# Episode: 650 	Score: -977.0
# Episode: 651 	Score: -968.0
# Episode: 652 	Score: -988.0
# Episode: 653 	Score: -989.0
# Episode: 654 	Score: -989.0
# Episode: 655 	Score: -981.0
# Episode: 656 	Score: -987.0
# Episode: 657 	Score: -974.0
# Episode: 658 	Score: -986.0
# Episode: 659 	Score: -992.0
# Episode: 660 	Score: -989.0
# Episode: 661 	Score: -980.0
# Episode: 662 	Score: -991.0
# Episode: 663 	Score: -983.0
# Episode: 664 	Score: -990.0
# Episode: 665 	Score: -956.0
# Episode: 666 	Score: -963.0
# Episode: 667 	Score: -989.0
# Episode: 668 	Score: -988.0
# Episode: 669 	Score: -966.0
# Episode: 670 	Score: -989.0
# Episode: 671 	Score: -967.0
# Episode: 672 	Score: -990.0
# Episode: 673 	Score: -977.0
# Episode: 674 	Score: -972.0
# Episode: 675 	Score: -986.0
# Episode: 676 	Score: -978.0
# Episode: 677 	Score: -981.0
# Episode: 678 	Score: -971.0
# Episode: 679 	Score: -991.0
# Episode: 680 	Score: -990.0
# Episode: 681 	Score: -972.0
# Episode: 682 	Score: -976.0
# Episode: 683 	Score: -985.0
# Episode: 684 	Score: -976.0
# Episode: 685 	Score: -984.0
# Episode: 686 	Score: -984.0
# Episode: 687 	Score: -970.0
# Episode: 688 	Score: -932.0
# Episode: 689 	Score: -988.0
# Episode: 690 	Score: -990.0
# Episode: 691 	Score: -991.0
# Episode: 692 	Score: -962.0
# Episode: 693 	Score: -989.0
# Episode: 694 	Score: -984.0
# Episode: 695 	Score: -990.0
# Episode: 696 	Score: -985.0
# Episode: 697 	Score: -983.0
# Episode: 698 	Score: -976.0
# Episode: 699 	Score: -985.0
# Episode: 700 	Score: -983.0
# Episode: 701 	Score: -943.0
# Episode: 702 	Score: -934.0
# Episode: 703 	Score: -963.0
# Episode: 704 	Score: -990.0
# Episode: 705 	Score: -975.0
# Episode: 706 	Score: -989.0
# Episode: 707 	Score: -982.0
# Episode: 708 	Score: -966.0
# Episode: 709 	Score: -976.0
# Episode: 710 	Score: -982.0
# Episode: 711 	Score: -962.0
# Episode: 712 	Score: -974.0
# Episode: 713 	Score: -981.0
# Episode: 714 	Score: -990.0
# Episode: 715 	Score: -917.0
# Episode: 716 	Score: -939.0
# Episode: 717 	Score: -991.0
# Episode: 718 	Score: -944.0
# Episode: 719 	Score: -963.0
# Episode: 720 	Score: -952.0
# Episode: 721 	Score: -991.0
# Episode: 722 	Score: -980.0
# Episode: 723 	Score: -986.0
# Episode: 724 	Score: -989.0
# Episode: 725 	Score: -971.0
# Episode: 726 	Score: -986.0
# Episode: 727 	Score: -989.0
# Episode: 728 	Score: -947.0
# Episode: 729 	Score: -984.0
# Episode: 730 	Score: -992.0
# Episode: 731 	Score: -992.0
# Episode: 732 	Score: -990.0
# Episode: 733 	Score: -988.0
# Episode: 734 	Score: -976.0
# Episode: 735 	Score: -990.0
# Episode: 736 	Score: -953.0
# Episode: 737 	Score: -961.0
# Episode: 738 	Score: -946.0
# Episode: 739 	Score: -962.0
# Episode: 740 	Score: -962.0
# Episode: 741 	Score: -986.0
# Episode: 742 	Score: -961.0
# Episode: 743 	Score: -990.0
# Episode: 744 	Score: -993.0
# Episode: 745 	Score: -991.0
# Episode: 746 	Score: -938.0
# Episode: 747 	Score: -992.0
# Episode: 748 	Score: -981.0
# Episode: 749 	Score: -987.0
# Episode: 750 	Score: -978.0
# Episode: 751 	Score: -978.0
# Episode: 752 	Score: -966.0
# Episode: 753 	Score: -928.0
# Episode: 754 	Score: -948.0
# Episode: 755 	Score: -990.0
# Episode: 756 	Score: -951.0
# Episode: 757 	Score: -981.0
# Episode: 758 	Score: -984.0
# Episode: 759 	Score: -989.0
# Episode: 760 	Score: -983.0
# Episode: 761 	Score: -982.0
# Episode: 762 	Score: -988.0
# Episode: 763 	Score: -977.0
# Episode: 764 	Score: -972.0
# Episode: 765 	Score: -974.0
# Episode: 766 	Score: -974.0
# Episode: 767 	Score: -971.0
# Episode: 768 	Score: -987.0
# Episode: 769 	Score: -961.0
# Episode: 770 	Score: -969.0
# Episode: 771 	Score: -947.0
# Episode: 772 	Score: -977.0
# Episode: 773 	Score: -991.0
# Episode: 774 	Score: -981.0
# Episode: 775 	Score: -990.0
# Episode: 776 	Score: -988.0
# Episode: 777 	Score: -990.0
# Episode: 778 	Score: -980.0
# Episode: 779 	Score: -986.0
# Episode: 780 	Score: -978.0
# Episode: 781 	Score: -982.0
# Episode: 782 	Score: -991.0
# Episode: 783 	Score: -990.0
# Episode: 784 	Score: -979.0
# Episode: 785 	Score: -983.0
# Episode: 786 	Score: -986.0
# Episode: 787 	Score: -969.0
# Episode: 788 	Score: -986.0
# Episode: 789 	Score: -991.0
# Episode: 790 	Score: -989.0
# Episode: 791 	Score: -964.0
# Episode: 792 	Score: -979.0
# Episode: 793 	Score: -990.0
# Episode: 794 	Score: -956.0
# Episode: 795 	Score: -980.0
# Episode: 796 	Score: -988.0
# Episode: 797 	Score: -980.0
# Episode: 798 	Score: -930.0
# Episode: 799 	Score: -960.0
# Episode: 800 	Score: -978.0
# Episode: 801 	Score: -986.0
# Episode: 802 	Score: -980.0
# Episode: 803 	Score: -950.0
# Episode: 804 	Score: -984.0
# Episode: 805 	Score: -990.0
# Episode: 806 	Score: -976.0
# Episode: 807 	Score: -968.0
# Episode: 808 	Score: -975.0
# Episode: 809 	Score: -992.0
# Episode: 810 	Score: -972.0
# Episode: 811 	Score: -947.0
# Episode: 812 	Score: -972.0
# Episode: 813 	Score: -987.0
# Episode: 814 	Score: -990.0
# Episode: 815 	Score: -990.0
# Episode: 816 	Score: -993.0
# Episode: 817 	Score: -937.0
# Episode: 818 	Score: -990.0
# Episode: 819 	Score: -984.0
# Episode: 820 	Score: -981.0
# Episode: 821 	Score: -980.0
# Episode: 822 	Score: -947.0
# Episode: 823 	Score: -961.0
# Episode: 824 	Score: -966.0
# Episode: 825 	Score: -966.0
# Episode: 826 	Score: -985.0
# Episode: 827 	Score: -966.0
# Episode: 828 	Score: -980.0
# Episode: 829 	Score: -989.0
# Episode: 830 	Score: -984.0
# Episode: 831 	Score: -884.0
# Episode: 832 	Score: -981.0
# Episode: 833 	Score: -987.0
# Episode: 834 	Score: -972.0
# Episode: 835 	Score: -987.0
# Episode: 836 	Score: -974.0
# Episode: 837 	Score: -979.0
# Episode: 838 	Score: -941.0
# Episode: 839 	Score: -982.0
# Episode: 840 	Score: -988.0
# Episode: 841 	Score: -990.0
# Episode: 842 	Score: -988.0
# Episode: 843 	Score: -985.0
# Episode: 844 	Score: -988.0
# Episode: 845 	Score: -975.0
# Episode: 846 	Score: -988.0
# Episode: 847 	Score: -988.0
# Episode: 848 	Score: -989.0
# Episode: 849 	Score: -982.0
# Episode: 850 	Score: -977.0
# Episode: 851 	Score: -982.0
# Episode: 852 	Score: -973.0
# Episode: 853 	Score: -978.0
# Episode: 854 	Score: -977.0
# Episode: 855 	Score: -987.0
# Episode: 856 	Score: -967.0
# Episode: 857 	Score: -976.0
# Episode: 858 	Score: -990.0
# Episode: 859 	Score: -989.0
# Episode: 860 	Score: -985.0
# Episode: 861 	Score: -947.0
# Episode: 862 	Score: -969.0
# Episode: 863 	Score: -984.0
# Episode: 864 	Score: -991.0
# Episode: 865 	Score: -989.0
# Episode: 866 	Score: -981.0
# Episode: 867 	Score: -988.0
# Episode: 868 	Score: -981.0
# Episode: 869 	Score: -983.0
# Episode: 870 	Score: -979.0
# Episode: 871 	Score: -984.0
# Episode: 872 	Score: -982.0
# Episode: 873 	Score: -978.0
# Episode: 874 	Score: -984.0
# Episode: 875 	Score: -983.0
# Episode: 876 	Score: -987.0
# Episode: 877 	Score: -985.0
# Episode: 878 	Score: -937.0
# Episode: 879 	Score: -990.0
# Episode: 880 	Score: -964.0
# Episode: 881 	Score: -970.0
# Episode: 882 	Score: -981.0
# Episode: 883 	Score: -982.0
# Episode: 884 	Score: -970.0
# Episode: 885 	Score: -981.0
# Episode: 886 	Score: -989.0
# Episode: 887 	Score: -951.0
# Episode: 888 	Score: -989.0
# Episode: 889 	Score: -971.0
# Episode: 890 	Score: -985.0
# Episode: 891 	Score: -989.0
# Episode: 892 	Score: -977.0
# Episode: 893 	Score: -992.0
# Episode: 894 	Score: -991.0
# Episode: 895 	Score: -992.0
# Episode: 896 	Score: -950.0
# Episode: 897 	Score: -987.0
# Episode: 898 	Score: -989.0
# Episode: 899 	Score: -983.0
# Episode: 900 	Score: -992.0
# Episode: 901 	Score: -989.0
# Episode: 902 	Score: -951.0
# Episode: 903 	Score: -982.0
# Episode: 904 	Score: -975.0
# Episode: 905 	Score: -942.0
# Episode: 906 	Score: -975.0
# Episode: 907 	Score: -986.0
# Episode: 908 	Score: -962.0
# Episode: 909 	Score: -982.0
# Episode: 910 	Score: -981.0
# Episode: 911 	Score: -989.0
# Episode: 912 	Score: -990.0
# Episode: 913 	Score: -986.0
# Episode: 914 	Score: -969.0
# Episode: 915 	Score: -988.0
# Episode: 916 	Score: -993.0
# Episode: 917 	Score: -968.0
# Episode: 918 	Score: -981.0
# Episode: 919 	Score: -961.0
# Episode: 920 	Score: -957.0
# Episode: 921 	Score: -982.0
# Episode: 922 	Score: -990.0
# Episode: 923 	Score: -982.0
# Episode: 924 	Score: -972.0
# Episode: 925 	Score: -989.0
# Episode: 926 	Score: -982.0
# Episode: 927 	Score: -985.0
# Episode: 928 	Score: -979.0
# Episode: 929 	Score: -990.0
# Episode: 930 	Score: -970.0
# Episode: 931 	Score: -988.0
# Episode: 932 	Score: -932.0
# Episode: 933 	Score: -978.0
# Episode: 934 	Score: -901.0
# Episode: 935 	Score: -974.0
# Episode: 936 	Score: -975.0
# Episode: 937 	Score: -992.0
# Episode: 938 	Score: -953.0
# Episode: 939 	Score: -988.0
# Episode: 940 	Score: -949.0
# Episode: 941 	Score: -990.0
# Episode: 942 	Score: -990.0
# Episode: 943 	Score: -987.0
# Episode: 944 	Score: -978.0
# Episode: 945 	Score: -979.0
# Episode: 946 	Score: -990.0
# Episode: 947 	Score: -991.0
# Episode: 948 	Score: -918.0
# Episode: 949 	Score: -989.0
# Episode: 950 	Score: -970.0
# Episode: 951 	Score: -988.0
# Episode: 952 	Score: -983.0
# Episode: 953 	Score: -981.0
# Episode: 954 	Score: -991.0
# Episode: 955 	Score: -990.0
# Episode: 956 	Score: -991.0
# Episode: 957 	Score: -989.0
# Episode: 958 	Score: -960.0
# Episode: 959 	Score: -961.0
# Episode: 960 	Score: -990.0
# Episode: 961 	Score: -987.0
# Episode: 962 	Score: -987.0
# Episode: 963 	Score: -985.0
# Episode: 964 	Score: -990.0
# Episode: 965 	Score: -989.0
# Episode: 966 	Score: -983.0
# Episode: 967 	Score: -976.0
# Episode: 968 	Score: -976.0
# Episode: 969 	Score: -983.0
# Episode: 970 	Score: -988.0
# Episode: 971 	Score: -965.0
# Episode: 972 	Score: -983.0
# Episode: 973 	Score: -980.0
# Episode: 974 	Score: -986.0
# Episode: 975 	Score: -987.0
# Episode: 976 	Score: -977.0
# Episode: 977 	Score: -988.0
# Episode: 978 	Score: -969.0
# Episode: 979 	Score: -980.0
# Episode: 980 	Score: -933.0
# Episode: 981 	Score: -978.0
# Episode: 982 	Score: -972.0
# Episode: 983 	Score: -990.0
# Episode: 984 	Score: -977.0
# Episode: 985 	Score: -971.0
# Episode: 986 	Score: -987.0
# Episode: 987 	Score: -987.0
# Episode: 988 	Score: -986.0
# Episode: 989 	Score: -934.0
# Episode: 990 	Score: -933.0
# Episode: 991 	Score: -959.0
# Episode: 992 	Score: -951.0
# Episode: 993 	Score: -975.0
# Episode: 994 	Score: -958.0
# Episode: 995 	Score: -942.0
# Episode: 996 	Score: -986.0
# Episode: 997 	Score: -964.0
# Episode: 998 	Score: -974.0
# Episode: 999 	Score: -987.0
# Episode: 1000 	Score: -948.0

# %%
print(a.q_table)
# Out:
# [[ 1.95289687e-01  4.78395347e-01]
#  [ 3.73893453e-01  4.76054985e-01]
#  [-5.69918924e+00  4.77830447e-01]
#  [ 8.81592894e+00 -1.42832244e+00]
#  [ 8.16246305e-01 -1.64831473e+00]
#  [ 1.29408276e+01  9.44881779e-01]
#  [ 8.74819077e+00  3.53855035e+00]
#  [-5.05061129e+01 -2.45548229e+02]
#  [ 5.33340467e+01 -3.66959305e+00]
#  [ 2.38539977e+01 -5.63622323e+01]
#  [-4.67922424e+02 -2.24614617e+02]
#  [-5.01166468e+02 -4.92576395e+02]
#  [-3.35085177e+02 -5.38971767e+02]
#  [ 0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00]
#  [-5.37765082e+02 -3.35006793e+02]
#  [-8.17992840e+02 -2.72164639e+01]
#  [ 2.39848040e+02 -3.68633445e+02]
#  [-8.84641004e+01 -3.48288507e+02]
#  [-1.37980778e+01 -1.23145866e+02]
#  [-2.22384587e+02 -4.29248736e+00]
#  [-2.30173317e+01 -8.16169329e+00]
#  [ 1.00630180e+01  1.05972916e+01]
#  [ 1.03101802e+00  1.42068450e+00]
#  [-5.61289371e-01  1.91694845e+00]
#  [ 4.71536819e-01  1.47953083e+00]
#  [ 5.26202448e-01 -1.61846047e-01]]

# %%
"""
a.evaluate(render=True)
"""
# Out:
#   Input In [1]
#     """a.evaluate(render=True)
#                               ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %% [markdown]
# ## Non-convergence Problem
# - Q-Agent is not complex enough
# - Requires knowledge of other observations such as angular velocity
# - Would create more dimensions to the q_table
#   - 3D array for one more parameter
#   - 4D array for two more parameters
#   - etc...
